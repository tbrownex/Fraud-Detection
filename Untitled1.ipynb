# %%
df = pd.read_csv("/home/tbrownex/NNresults.csv")

# %%
df["L1Size"].describe()
# Out:
# count    100.00000
# mean      60.80000
# std       39.97575
# min       16.00000
# 25%       32.00000
# 50%       64.00000
# 75%       64.00000
# max      128.00000
# Name: L1Size, dtype: float64

# %%
df.corr()["G-score"]
# Out:
# F1-score        0.944337
# FalseNeg       -0.605241
# FalsePos        0.045743
# G-score         1.000000
# L1Size         -0.364046
# TruePos         0.605241
# auc             0.731664
# batchSize            NaN
# clsWeight       0.043992
# dropout        -0.106144
# learningRate    0.056434
# loss            0.066395
# precision       0.659423
# recall          0.605160
# Name: G-score, dtype: float64

# %%
df.sample(10)
# Out:
#     F1-score  FalseNeg  FalsePos  G-score  L1Size  TruePos activation    auc  \
# 26      0.18      13.0     785.0     0.29      32     85.0       relu  0.962
# 88      0.18      14.0     758.0     0.29      32     84.0       relu  0.959
# 17      0.16      13.0     896.0     0.27      32     85.0       relu  0.959
# 0       0.15      12.0     982.0     0.27      16     86.0       relu  0.961
# 19      0.10      13.0    1485.0     0.22      64     85.0       relu  0.966
# 14      0.10      12.0    1591.0     0.21      64     86.0       relu  0.962
# 53      0.16      14.0     859.0     0.28      16     84.0       relu  0.962
# 65      0.14      13.0    1036.0     0.26     128     85.0       relu  0.958
# 80      0.15      13.0     932.0     0.27      32     85.0       relu  0.959
# 57      0.12      12.0    1229.0     0.24     128     86.0       relu  0.954
#
#     batchSize  clsWeight   dropout  learningRate      loss  precision  recall
# ...

# %%
df.sort_values("F1-score", ascending=False)[:5]
# Out:
#     F1-score  FalseNeg  FalsePos  G-score  L1Size  TruePos activation    auc  \
# 39      0.52      58.0      17.0     0.54      16     40.0       relu  0.891
# 67      0.20      14.0     645.0     0.31     128     84.0       relu  0.959
# 63      0.19      14.0     721.0     0.30      64     84.0       relu  0.963
# 77      0.19      13.0     699.0     0.31      32     85.0       relu  0.964
# 26      0.18      13.0     785.0     0.29      32     85.0       relu  0.962
#
#     batchSize  clsWeight   dropout  learningRate      loss  precision  recall
# 39       2048        181  0.317387         0.000  0.009150      0.702   0.408
# 67       2048         89  0.329885         0.002  0.057712      0.115   0.857
# 63       2048         88  0.420394         0.002  0.056317      0.104   0.857
# 77       2048        118  0.442648         0.005  0.054429      0.108   0.867
# 26       2048        166  0.481483         0.002  0.064561      0.098   0.867

# %%
df[df["activation"] == "tanh"]["F1-score"].mean()
# Out:
# 0.3913636363636364

# %%
df["dropout"].describe()
# Out:
# count    100.000000
# mean       0.350218
# std        0.085860
# min        0.210377
# 25%        0.271063
# 50%        0.342521
# 75%        0.429732
# max        0.491566
# Name: dropout, dtype: float64
